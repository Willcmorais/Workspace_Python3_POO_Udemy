# %% [markdown]
# # Configurações e informações iniciais:
#
# > Vamos baixar o Python e o VS Code.
#
# - Criamos uma pasta e damos o comando `python -m venv venv` e criamos a pasta venv.
# - instalação e configuração do powershell(Como admn) para ativar o `venv.`
# - Para a ativação do venv é necessário utilizar este código no powershell admn: `Set-ExecutionPolicy RemoteSigned -Scope CurrentUser -Force`.
# - Código para ativação `.\venv\Scripts\activate`
# - Comando `clear` limpa o terminal
# - Para executar dois comandos ao mesmo tempo no powershell nós utilizamos o `;`. Por exemplo `clear;ls`
# - Para fazer comentário no python utilizamos o # para inlines e aspas triplas`(""" ou ''')` para comentários `DocStrings`

# %% [markdown]
# # Atalhos do VS Code:
#
# - Se dermos`CTRL + C` apenas na linha, sem selecionar, ele copia a linha inteira e joga pra baixo.
# - Caixa de Comando:
# `Ctrl + Shift + P` (Abrir a caixa de comando para pesquisar funcionalidades).
# - `Ctrl + G` (Ir para uma linha específica do arquivo).
# - `Ctrl + Shift + O` (Navegar pelo esquema do arquivo).
# - `Ctrl + Alt + Seta para cima ou para baixo` (Mover a linha atual para cima ou para baixo).
# - `Ctrl + /` (Comentar ou descomentar a seleção atual).
# - `Shift + Alt + F` (Formatar o documento).

# %% [markdown]
# # Configurações do VS Code:
#
# - `Explorer.compactFolders: false` - Para não compactar as pastas do menu lateral.
# - Baixar extensão do python e code runner. No code runner > settings vamos alterar o `runInTerminal: true, clearPreviousOutput: true, executorMap{python: cls ; python - u}`
# - Mudando o tema para o `Atom One Light`
# - Mudando a visualização de pastas com o `Material icon theme`
# - Settings: `default interpreter path: python`

# %% [markdown]
# # Introdução ao assunto:
#
# - Por padrão o print utiliza o separador de espaço entre os argumentos.
# - Podemos trocar o tipo do separados dos prints com o comando `, sep=''` no final dos argumentos.
# - Também podemos utilizar o argumento `, end=' '` para no final da frase ela receber o parâmetro informado.

# %%
print(234, 123)
print(234, 123, sep='-', end='##')
print(234, 123, sep='-', end='\n##')
print(5555)
# Out:
# 234 123
# 234-123##234-123
# ##5555

# %% [markdown]
# # Tipos de dados:
#
# - Todas as linguagens tem uma característica. Podemos ter tipagens fracas, fortes, dinâmicas ou estáticas.
# - Python tem tipagem Dinâmica / Forte.
# - Para deixar o código mais limpo podemos utilizar das aspas simples para mostrar strings e, caso seja necessário utilizar uma aspas no texto, essa aspas pode ser a dupla.

# %%
"""
DocString
Python = Linguagem de programação
Tipo de tipagem = Dinâmica / Forte
str -> string -> texto
Strings são textos que estão dentro de aspas
"""
print(1234)

# Aspas simples
print('Luiz Otávio')
print(1, 'Luiz "Otávio"')

# Aspas duplas
print("Luiz Otávio")
print(2, "Luiz 'Otávio'")

# Escape
print("Luiz \"Otávio\"")

# r (regular expressions)
print(r"Luiz \"Otávio\"")
# Out:
# 1234
# Luiz Otávio
# 1 Luiz "Otávio"
# Luiz Otávio
# 2 Luiz 'Otávio'
# Luiz "Otávio"
# Luiz \"Otávio\"

# %% [markdown]
# # Tipos primitivos:
#
# > Tipos int e float:
#
# - `int` -> Número inteiro. O tipo int representa qualquer número, positivo ou negativo. int sem sinal é considerado positivo.
#
# - `float` -> Número com ponto flutuante. O tipo float representa qualquer número positivo ou negativo com ponto flutuante, float sem sinal é considerado positivo.
#
# - A função `type` mostra o tipo que o Python inferiu ao valor.
#
# - Tipo de dado `bool` (boolean): Ao questionar algo em um programa, só existem duas respostas possíveis, sim (True) ou não (False).
#
# - Existem vários operadores para "questionar". Dentre eles o `==`, que é um operador lógico que questiona se um valor é igual a outro.

# %%
print(type('Otávio'))
print(type(0))
print(type(1.1), type(-1.1), type(0.0))

print(10 == 10)
print(10 == 11)
print(type(True))
print(type(False))
print(type(10 == 10))
print(type(10 == 11))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'> <class 'float'> <class 'float'>
# True
# False
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# # Conversão de dados:
#
# - As vezes precisamos fazer operações com dois valores
# - Outros nomes: Conversão de tipos, coerção, type convertion, typecasting, coercion
# - É o ato de converter um tipo em outro tipos imutáveis e primitivos: `str, int, float, bool`
# - `print(int('1'), type(int('1')))`: Neste caso nós forçamos o tipo entre parênteses(string) ser um typoe int.
# - `print('a' + 'b')`:  São tipos string, então, o + vai ser utilizado como concatenar.
# - OBS: Para booleanos, quando temos algum valor, consideramos `True`, quando está vazio é considerado `False`.

# %%
print(int('1'), type(int('1')))
print('a' + 'b')
print((float('1.2') + 1), type(float('1.2') + 1))
print(bool(' '))
print(str(11) + 'b')
print(11 + 'b') # teste de erro.
# Out:
# 1 <class 'int'>
# ab
# 2.2 <class 'float'>
# True
# 11b
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-939752761.py in <cell line: 0>()
#       4 print(bool(' '))
#       5 print(str(11) + 'b')
# ----> 6 print(11 + 'b') # teste de erro.
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Variáveis:
#
# - São usadas para salvar algo na memória do computador.
#
# - PEP 8(Guia de estilos do código, como escrever os códigos): `inicie variáveis com letras minúsculas, pode usar números e underline _`.
#
# - O sinal de `=` é o operador de atribuição. Ele é usado para atribuir um valor a um nome (variável).
# > Uso: nome_variavel = 'expressão'

# %%
nome_completo = 'Luiz Otávio Miranda'
soma_dois_mais_dois = 2 + 2
int_um = bool('1') # Devemos ter cuidado quanto a nomeação de variáveis assim. Neste caso estaria errado, pois, o nome é inteiro mas é um tipo booleano.
print(int_um, type(int_um))
print(nome_completo, soma_dois_mais_dois)

nome = 'Luiz'
idade = 17
maior_de_idade = idade >= 18 # valor booleano
print('Nome:', nome, '\nIdade:', idade)
print('É maior?', maior_de_idade)
# Out:
# True <class 'bool'>
# Luiz Otávio Miranda 4
# Nome: Luiz
# Idade: 17
# É maior? False

# %% [markdown]
# > Exercício de fixação:

# %%
nome = 'William'
sobrenome = 'Coelho'
idade = int(28)
ano_nascimento = 2025 - idade
maior_de_idade = idade >= 18
altura_metros = float(1.85)

print('Nome:', nome)
print('Sobrenome:', sobrenome)
print('Idade:', idade)
print('Ano de nascimento:', ano_nascimento)
print('É maior de idade?', maior_de_idade)
print('Altura em metros:', altura_metros)
# Out:
# Nome: William
# Sobrenome: Coelho
# Idade: 28
# Ano de nascimento: 1997
# É maior de idade? True
# Altura em metros: 1.85

# %% [markdown]
# # Introdução aos operadores aritiméticos:
#
# - Operadores: `+, -, *, /, //(Divisão inteira), **(Exponenciação), %(Resto da divisão)`.
# - Quando utilizamos duas strings com o sinal de '+' nós iremos concatenar a informação.
# - Exemplos:
#
# > `concatenacao = 'A'+'B'+'C'`. Isso vai dar `'ABC'`.
#
# > `nome_completo = 'William'+' '+'Coelho'`. Isso vai dar `William Coelho`.
#
# > `a_dez_vezes = 'A'*10`. Isso vai dar `AAAAAAAAAA`.
#
# > `tres_vezes_will = 3*'Will'`. Isso vai dar `WillWillWill`.
#
# # Precedência entre os operadores:
# - Caso a precedência seja igual entre os operadores, a ordem de execução será da esquerda para a direita.
#
# - 1 - `(n + n)`
# - Os parênteses mais internos são executados primeiro.
#
# - 2 - `**`
#
# - 3 - `* / // %`
#
# - 4 - `+ -`

# %%
adicao = 10 + 10
print('Adição', adicao)

subtracao = 10 - 5
print('Subtração', subtracao)

multiplicacao = 10 * 10
print('Multiplicação', multiplicacao)

divisao = 10 / 3  # float
print('Divisão', divisao)

divisao_inteira = 10 // 3
print('Divisão inteira', divisao_inteira)

exponenciacao = 2 ** 10
print('Exponenciação', exponenciacao)

modulo = 55 % 2  # resto da divisão
print('Módulo', modulo)

print(10 % 8 == 0)
print(16 % 8 == 0)
print(10 % 2 == 0) # útil para saber se o número é par ou impar.
print(15 % 2 == 0)
print(16 % 2 == 0)

conta_1 = 1 + 1 ** 5 + 5 # 7
conta_1 = (1 + 1) ** (5 + 5) #1024
print(conta_1)

conta_2 = 2**10
print(conta_2)

conta_1 = (1 + int(0.5 + 0.5)) ** (5 + 5) #1024
print(conta_1)
# Out:
# Adição 20
# Subtração 5
# Multiplicação 100
# Divisão 3.3333333333333335
# Divisão inteira 3
# Exponenciação 1024
# Módulo 1
# False
# True
# True
# False
# True
# 1024
# 1024
# 1024

# %% [markdown]
# > Exercício de fixação:
#
# - O `...` é chamado de `Ellipsis`. Pode ser usado como `PlaceHolder`, isto faz com que possamos declarar uma variável sem valor e não gera erros.

# %%
nome = 'Jorge Manoel'
altura = 1.80
peso = 95
imc = peso / (altura * altura)
# imc = ...

# print(nome, 'tem', altura, 'de altura ')
# print('Pesa', peso, 'quilos')
# print('O seu IMC é de', imc)

print(peso / (altura*2)) # 1.80 * 1.80 = 3.6 -> 95/3.6 = 26.38.
print(peso / altura*2) # 95/1.80 = 52.7 -> 52.7*2 = 105.5.

print(peso / (altura * altura)) # 1.8 * 1.8 = 3.24 -> 95/3.24 = 29.32.
print(peso / altura * altura) # 95/1.80 = 52.77 -> 52.77*1.80 = 95.0.

print(peso / (altura**2)) # conta correta.
print(peso / altura**2) # igual ao de cima, conta correta.
# Out:
# 26.38888888888889
# 105.55555555555556
# 29.320987654320987
# 95.0
# 29.320987654320987
# 29.320987654320987
